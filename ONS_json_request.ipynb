# %% [markdown]
# # A brief JSON request example using Python
#
# Here I made a request to the Office for National Statistics (ONS) API. The specific dataset is related to wellbeing.
# I read the response into a Python dictionary.
# I then chained indexing operations to pull information from the dictionary.

# %%
import requests
import json 
import pandas as pd 

# Making a GET request to the specified API endpoint
response = requests.get("https://api.beta.ons.gov.uk/v1/datasets/TS008/editions/2021/versions/1/json")
# Parsing the JSON response into a Python dictionary
raw = response.json()

# Extracting information from the JSON data by chaining indexing operations
areas = raw['dimensions'][0]['options']  # Extracting geographical area info
sexes = raw['dimensions'][1]['options'] # Extracting sex info
obs = raw['observations'] # Extracting observations (data associated with the area and sex dimensions)

# Creating a pandas DataFrame from the 'areas' data
df = pd.DataFrame(obs)

# %% [markdown]
# Here you can see that I have successfully extracted the areas included within the dataset.

# %%
areas
# Out:
# [{'href': '', 'id': 'E06000001', 'label': 'Hartlepool'},
#  {'href': '', 'id': 'E06000002', 'label': 'Middlesbrough'},
#  {'href': '', 'id': 'E06000003', 'label': 'Redcar and Cleveland'},
#  {'href': '', 'id': 'E06000004', 'label': 'Stockton-on-Tees'},
#  {'href': '', 'id': 'E06000005', 'label': 'Darlington'},
#  {'href': '', 'id': 'E06000006', 'label': 'Halton'},
#  {'href': '', 'id': 'E06000007', 'label': 'Warrington'},
#  {'href': '', 'id': 'E06000008', 'label': 'Blackburn with Darwen'},
#  {'href': '', 'id': 'E06000009', 'label': 'Blackpool'},
#  {'href': '', 'id': 'E06000010', 'label': 'Kingston upon Hull'},
#  {'href': '', 'id': 'E06000011', 'label': 'East Riding of Yorkshire'},
#  {'href': '', 'id': 'E06000012', 'label': 'North East Lincolnshire'},
#  {'href': '', 'id': 'E06000013', 'label': 'North Lincolnshire'},
#  {'href': '', 'id': 'E06000014', 'label': 'York'},
#  {'href': '', 'id': 'E06000015', 'label': 'Derby'},
#  {'href': '', 'id': 'E06000016', 'label': 'Leicester'},
#  {'href': '', 'id': 'E06000017', 'label': 'Rutland'},
#  {'href': '', 'id': 'E06000018', 'label': 'Nottingham'},
#  {'href': '', 'id': 'E06000019', 'label': 'Herefordshire'},
#  {'href': '', 'id': 'E06000020', 'label': 'Telford and Wrekin'},
#  {'href': '', 'id': 'E06000021', 'label': 'Stoke-on-Trent'},
#  {'href': '', 'id': 'E06000022', 'label': 'Bath and North East Somerset'},
#  {'href': '', 'id': 'E06000023', 'label': 'Bristol'},
#  {'href': '', 'id': 'E06000024', 'label': 'North Somerset'},
#  {'href': '', 'id': 'E06000025', 'label': 'South Gloucestershire'},
#  {'href': '', 'id': 'E06000026', 'label': 'Plymouth'},
#  {'href': '', 'id': 'E06000027', 'label': 'Torbay'},
#  {'href': '', 'id': 'E06000030', 'label': 'Swindon'},
#  {'href': '', 'id': 'E06000031', 'label': 'Peterborough'},
#  {'href': '', 'id': 'E06000032', 'label': 'Luton'},
#  {'href': '', 'id': 'E06000033', 'label': 'Southend-on-Sea'},
#  {'href': '', 'id': 'E06000034', 'label': 'Thurrock'},
#  {'href': '', 'id': 'E06000035', 'label': 'Medway'},
#  {'href': '', 'id': 'E06000036', 'label': 'Bracknell Forest'},
#  {'href': '', 'id': 'E06000037', 'label': 'West Berkshire'},
#  {'href': '', 'id': 'E06000038', 'label': 'Reading'},
#  {'href': '', 'id': 'E06000039', 'label': 'Slough'},
#  {'href': '', 'id': 'E06000040', 'label': 'Windsor and Maidenhead'},
#  {'href': '', 'id': 'E06000041', 'label': 'Wokingham'},
#  {'href': '', 'id': 'E06000042', 'label': 'Milton Keynes'},
#  {'href': '', 'id': 'E06000043', 'label': 'Brighton and Hove'},
#  {'href': '', 'id': 'E06000044', 'label': 'Portsmouth'},
#  {'href': '', 'id': 'E06000045', 'label': 'Southampton'},
#  {'href': '', 'id': 'E06000046', 'label': 'Isle of Wight'},
#  {'href': '', 'id': 'E06000047', 'label': 'County Durham'},
#  {'href': '', 'id': 'E06000049', 'label': 'Cheshire East'},
#  {'href': '', 'id': 'E06000050', 'label': 'Cheshire West and Chester'},
#  {'href': '', 'id': 'E06000051', 'label': 'Shropshire'},
#  {'href': '', 'id': 'E06000052', 'label': 'Cornwall'},
#  {'href': '', 'id': 'E06000053', 'label': 'Isles of Scilly'},
#  {'href': '', 'id': 'E06000054', 'label': 'Wiltshire'},
#  {'href': '', 'id': 'E06000055', 'label': 'Bedford'},
#  {'href': '', 'id': 'E06000056', 'label': 'Central Bedfordshire'},
#  {'href': '', 'id': 'E06000057', 'label': 'Northumberland'},
#  {'href': '',
#   'id': 'E06000058',
#   'label': 'Bournemouth, Christchurch and Poole'},
#  {'href': '', 'id': 'E06000059', 'label': 'Dorset'},
#  {'href': '', 'id': 'E06000060', 'label': 'Buckinghamshire'},
#  {'href': '', 'id': 'E06000061', 'label': 'North Northamptonshire'},
#  {'href': '', 'id': 'E06000062', 'label': 'West Northamptonshire'},
#  {'href': '', 'id': 'E07000008', 'label': 'Cambridge'},
#  {'href': '', 'id': 'E07000009', 'label': 'East Cambridgeshire'},
#  {'href': '', 'id': 'E07000010', 'label': 'Fenland'},
#  {'href': '', 'id': 'E07000011', 'label': 'Huntingdonshire'},
#  {'href': '', 'id': 'E07000012', 'label': 'South Cambridgeshire'},
#  {'href': '', 'id': 'E07000026', 'label': 'Allerdale'},
#  {'href': '', 'id': 'E07000027', 'label': 'Barrow-in-Furness'},
#  {'href': '', 'id': 'E07000028', 'label': 'Carlisle'},
#  {'href': '', 'id': 'E07000029', 'label': 'Copeland'},
#  {'href': '', 'id': 'E07000030', 'label': 'Eden'},
#  {'href': '', 'id': 'E07000031', 'label': 'South Lakeland'},
#  {'href': '', 'id': 'E07000032', 'label': 'Amber Valley'},
#  {'href': '', 'id': 'E07000033', 'label': 'Bolsover'},
#  {'href': '', 'id': 'E07000034', 'label': 'Chesterfield'},
#  {'href': '', 'id': 'E07000035', 'label': 'Derbyshire Dales'},
#  {'href': '', 'id': 'E07000036', 'label': 'Erewash'},
#  {'href': '', 'id': 'E07000037', 'label': 'High Peak'},
#  {'href': '', 'id': 'E07000038', 'label': 'North East Derbyshire'},
#  {'href': '', 'id': 'E07000039', 'label': 'South Derbyshire'},
#  {'href': '', 'id': 'E07000040', 'label': 'East Devon'},
#  {'href': '', 'id': 'E07000041', 'label': 'Exeter'},
#  {'href': '', 'id': 'E07000042', 'label': 'Mid Devon'},
#  {'href': '', 'id': 'E07000043', 'label': 'North Devon'},
#  {'href': '', 'id': 'E07000044', 'label': 'South Hams'},
#  {'href': '', 'id': 'E07000045', 'label': 'Teignbridge'},
#  {'href': '', 'id': 'E07000046', 'label': 'Torridge'},
#  {'href': '', 'id': 'E07000047', 'label': 'West Devon'},
#  {'href': '', 'id': 'E07000061', 'label': 'Eastbourne'},
#  {'href': '', 'id': 'E07000062', 'label': 'Hastings'},
#  {'href': '', 'id': 'E07000063', 'label': 'Lewes'},
#  {'href': '', 'id': 'E07000064', 'label': 'Rother'},
#  {'href': '', 'id': 'E07000065', 'label': 'Wealden'},
#  {'href': '', 'id': 'E07000066', 'label': 'Basildon'},
#  {'href': '', 'id': 'E07000067', 'label': 'Braintree'},
#  {'href': '', 'id': 'E07000068', 'label': 'Brentwood'},
#  {'href': '', 'id': 'E07000069', 'label': 'Castle Point'},
#  {'href': '', 'id': 'E07000070', 'label': 'Chelmsford'},
#  {'href': '', 'id': 'E07000071', 'label': 'Colchester'},
#  {'href': '', 'id': 'E07000072', 'label': 'Epping Forest'},
#  {'href': '', 'id': 'E07000073', 'label': 'Harlow'},
#  {'href': '', 'id': 'E07000074', 'label': 'Maldon'},
#  {'href': '', 'id': 'E07000075', 'label': 'Rochford'},
#  {'href': '', 'id': 'E07000076', 'label': 'Tendring'},
#  {'href': '', 'id': 'E07000077', 'label': 'Uttlesford'},
#  {'href': '', 'id': 'E07000078', 'label': 'Cheltenham'},
#  {'href': '', 'id': 'E07000079', 'label': 'Cotswold'},
#  {'href': '', 'id': 'E07000080', 'label': 'Forest of Dean'},
#  {'href': '', 'id': 'E07000081', 'label': 'Gloucester'},
#  {'href': '', 'id': 'E07000082', 'label': 'Stroud'},
#  {'href': '', 'id': 'E07000083', 'label': 'Tewkesbury'},
#  {'href': '', 'id': 'E07000084', 'label': 'Basingstoke and Deane'},
#  {'href': '', 'id': 'E07000085', 'label': 'East Hampshire'},
#  {'href': '', 'id': 'E07000086', 'label': 'Eastleigh'},
#  {'href': '', 'id': 'E07000087', 'label': 'Fareham'},
#  {'href': '', 'id': 'E07000088', 'label': 'Gosport'},
#  {'href': '', 'id': 'E07000089', 'label': 'Hart'},
#  {'href': '', 'id': 'E07000090', 'label': 'Havant'},
#  {'href': '', 'id': 'E07000091', 'label': 'New Forest'},
#  {'href': '', 'id': 'E07000092', 'label': 'Rushmoor'},
#  {'href': '', 'id': 'E07000093', 'label': 'Test Valley'},
#  {'href': '', 'id': 'E07000094', 'label': 'Winchester'},
#  {'href': '', 'id': 'E07000095', 'label': 'Broxbourne'},
#  {'href': '', 'id': 'E07000096', 'label': 'Dacorum'},
#  {'href': '', 'id': 'E07000098', 'label': 'Hertsmere'},
#  {'href': '', 'id': 'E07000099', 'label': 'North Hertfordshire'},
#  {'href': '', 'id': 'E07000102', 'label': 'Three Rivers'},
#  {'href': '', 'id': 'E07000103', 'label': 'Watford'},
#  {'href': '', 'id': 'E07000105', 'label': 'Ashford'},
#  {'href': '', 'id': 'E07000106', 'label': 'Canterbury'},
#  {'href': '', 'id': 'E07000107', 'label': 'Dartford'},
#  {'href': '', 'id': 'E07000108', 'label': 'Dover'},
#  {'href': '', 'id': 'E07000109', 'label': 'Gravesham'},
#  {'href': '', 'id': 'E07000110', 'label': 'Maidstone'},
#  {'href': '', 'id': 'E07000111', 'label': 'Sevenoaks'},
#  {'href': '', 'id': 'E07000112', 'label': 'Folkestone and Hythe'},
#  {'href': '', 'id': 'E07000113', 'label': 'Swale'},
#  {'href': '', 'id': 'E07000114', 'label': 'Thanet'},
#  {'href': '', 'id': 'E07000115', 'label': 'Tonbridge and Malling'},
#  {'href': '', 'id': 'E07000116', 'label': 'Tunbridge Wells'},
#  {'href': '', 'id': 'E07000117', 'label': 'Burnley'},
#  {'href': '', 'id': 'E07000118', 'label': 'Chorley'},
#  {'href': '', 'id': 'E07000119', 'label': 'Fylde'},
#  {'href': '', 'id': 'E07000120', 'label': 'Hyndburn'},
#  {'href': '', 'id': 'E07000121', 'label': 'Lancaster'},
#  {'href': '', 'id': 'E07000122', 'label': 'Pendle'},
#  {'href': '', 'id': 'E07000123', 'label': 'Preston'},
#  {'href': '', 'id': 'E07000124', 'label': 'Ribble Valley'},
#  {'href': '', 'id': 'E07000125', 'label': 'Rossendale'},
#  {'href': '', 'id': 'E07000126', 'label': 'South Ribble'},
#  {'href': '', 'id': 'E07000127', 'label': 'West Lancashire'},
#  {'href': '', 'id': 'E07000128', 'label': 'Wyre'},
#  {'href': '', 'id': 'E07000129', 'label': 'Blaby'},
#  {'href': '', 'id': 'E07000130', 'label': 'Charnwood'},
#  {'href': '', 'id': 'E07000131', 'label': 'Harborough'},
#  {'href': '', 'id': 'E07000132', 'label': 'Hinckley and Bosworth'},
#  {'href': '', 'id': 'E07000133', 'label': 'Melton'},
#  {'href': '', 'id': 'E07000134', 'label': 'North West Leicestershire'},
#  {'href': '', 'id': 'E07000135', 'label': 'Oadby and Wigston'},
#  {'href': '', 'id': 'E07000136', 'label': 'Boston'},
#  {'href': '', 'id': 'E07000137', 'label': 'East Lindsey'},
#  {'href': '', 'id': 'E07000138', 'label': 'Lincoln'},
#  {'href': '', 'id': 'E07000139', 'label': 'North Kesteven'},
#  {'href': '', 'id': 'E07000140', 'label': 'South Holland'},
#  {'href': '', 'id': 'E07000141', 'label': 'South Kesteven'},
#  {'href': '', 'id': 'E07000142', 'label': 'West Lindsey'},
#  {'href': '', 'id': 'E07000143', 'label': 'Breckland'},
#  {'href': '', 'id': 'E07000144', 'label': 'Broadland'},
#  {'href': '', 'id': 'E07000145', 'label': 'Great Yarmouth'},
#  {'href': '', 'id': 'E07000146', 'label': "King's Lynn and West Norfolk"},
#  {'href': '', 'id': 'E07000147', 'label': 'North Norfolk'},
#  {'href': '', 'id': 'E07000148', 'label': 'Norwich'},
#  {'href': '', 'id': 'E07000149', 'label': 'South Norfolk'},
#  {'href': '', 'id': 'E07000163', 'label': 'Craven'},
#  {'href': '', 'id': 'E07000164', 'label': 'Hambleton'},
#  {'href': '', 'id': 'E07000165', 'label': 'Harrogate'},
#  {'href': '', 'id': 'E07000166', 'label': 'Richmondshire'},
#  {'href': '', 'id': 'E07000167', 'label': 'Ryedale'},
#  {'href': '', 'id': 'E07000168', 'label': 'Scarborough'},
#  {'href': '', 'id': 'E07000169', 'label': 'Selby'},
#  {'href': '', 'id': 'E07000170', 'label': 'Ashfield'},
#  {'href': '', 'id': 'E07000171', 'label': 'Bassetlaw'},
#  {'href': '', 'id': 'E07000172', 'label': 'Broxtowe'},
#  {'href': '', 'id': 'E07000173', 'label': 'Gedling'},
#  {'href': '', 'id': 'E07000174', 'label': 'Mansfield'},
#  {'href': '', 'id': 'E07000175', 'label': 'Newark and Sherwood'},
#  {'href': '', 'id': 'E07000176', 'label': 'Rushcliffe'},
#  {'href': '', 'id': 'E07000177', 'label': 'Cherwell'},
#  {'href': '', 'id': 'E07000178', 'label': 'Oxford'},
#  {'href': '', 'id': 'E07000179', 'label': 'South Oxfordshire'},
#  {'href': '', 'id': 'E07000180', 'label': 'Vale of White Horse'},
#  {'href': '', 'id': 'E07000181', 'label': 'West Oxfordshire'},
#  {'href': '', 'id': 'E07000187', 'label': 'Mendip'},
#  {'href': '', 'id': 'E07000188', 'label': 'Sedgemoor'},
#  {'href': '', 'id': 'E07000189', 'label': 'South Somerset'},
#  {'href': '', 'id': 'E07000192', 'label': 'Cannock Chase'},
#  {'href': '', 'id': 'E07000193', 'label': 'East Staffordshire'},
#  {'href': '', 'id': 'E07000194', 'label': 'Lichfield'},
#  {'href': '', 'id': 'E07000195', 'label': 'Newcastle-under-Lyme'},
#  {'href': '', 'id': 'E07000196', 'label': 'South Staffordshire'},
#  {'href': '', 'id': 'E07000197', 'label': 'Stafford'},
#  {'href': '', 'id': 'E07000198', 'label': 'Staffordshire Moorlands'},
#  {'href': '', 'id': 'E07000199', 'label': 'Tamworth'},
#  {'href': '', 'id': 'E07000200', 'label': 'Babergh'},
#  {'href': '', 'id': 'E07000202', 'label': 'Ipswich'},
#  {'href': '', 'id': 'E07000203', 'label': 'Mid Suffolk'},
#  {'href': '', 'id': 'E07000207', 'label': 'Elmbridge'},
#  {'href': '', 'id': 'E07000208', 'label': 'Epsom and Ewell'},
#  {'href': '', 'id': 'E07000209', 'label': 'Guildford'},
#  {'href': '', 'id': 'E07000210', 'label': 'Mole Valley'},
#  {'href': '', 'id': 'E07000211', 'label': 'Reigate and Banstead'},
#  {'href': '', 'id': 'E07000212', 'label': 'Runnymede'},
#  {'href': '', 'id': 'E07000213', 'label': 'Spelthorne'},
#  {'href': '', 'id': 'E07000214', 'label': 'Surrey Heath'},
#  {'href': '', 'id': 'E07000215', 'label': 'Tandridge'},
#  {'href': '', 'id': 'E07000216', 'label': 'Waverley'},
#  {'href': '', 'id': 'E07000217', 'label': 'Woking'},
#  {'href': '', 'id': 'E07000218', 'label': 'North Warwickshire'},
#  {'href': '', 'id': 'E07000219', 'label': 'Nuneaton and Bedworth'},
#  {'href': '', 'id': 'E07000220', 'label': 'Rugby'},
#  {'href': '', 'id': 'E07000221', 'label': 'Stratford-on-Avon'},
#  {'href': '', 'id': 'E07000222', 'label': 'Warwick'},
#  {'href': '', 'id': 'E07000223', 'label': 'Adur'},
#  {'href': '', 'id': 'E07000224', 'label': 'Arun'},
#  {'href': '', 'id': 'E07000225', 'label': 'Chichester'},
#  {'href': '', 'id': 'E07000226', 'label': 'Crawley'},
#  {'href': '', 'id': 'E07000227', 'label': 'Horsham'},
#  {'href': '', 'id': 'E07000228', 'label': 'Mid Sussex'},
#  {'href': '', 'id': 'E07000229', 'label': 'Worthing'},
#  {'href': '', 'id': 'E07000234', 'label': 'Bromsgrove'},
#  {'href': '', 'id': 'E07000235', 'label': 'Malvern Hills'},
#  {'href': '', 'id': 'E07000236', 'label': 'Redditch'},
#  {'href': '', 'id': 'E07000237', 'label': 'Worcester'},
#  {'href': '', 'id': 'E07000238', 'label': 'Wychavon'},
#  {'href': '', 'id': 'E07000239', 'label': 'Wyre Forest'},
#  {'href': '', 'id': 'E07000240', 'label': 'St Albans'},
#  {'href': '', 'id': 'E07000241', 'label': 'Welwyn Hatfield'},
#  {'href': '', 'id': 'E07000242', 'label': 'East Hertfordshire'},
#  {'href': '', 'id': 'E07000243', 'label': 'Stevenage'},
#  {'href': '', 'id': 'E07000244', 'label': 'East Suffolk'},
#  {'href': '', 'id': 'E07000245', 'label': 'West Suffolk'},
#  {'href': '', 'id': 'E07000246', 'label': 'Somerset West and Taunton'},
#  {'href': '', 'id': 'E08000001', 'label': 'Bolton'},
#  {'href': '', 'id': 'E08000002', 'label': 'Bury'},
#  {'href': '', 'id': 'E08000003', 'label': 'Manchester'},
#  {'href': '', 'id': 'E08000004', 'label': 'Oldham'},
#  {'href': '', 'id': 'E08000005', 'label': 'Rochdale'},
#  {'href': '', 'id': 'E08000006', 'label': 'Salford'},
#  {'href': '', 'id': 'E08000007', 'label': 'Stockport'},
#  {'href': '', 'id': 'E08000008', 'label': 'Tameside'},
#  {'href': '', 'id': 'E08000009', 'label': 'Trafford'},
#  {'href': '', 'id': 'E08000010', 'label': 'Wigan'},
#  {'href': '', 'id': 'E08000011', 'label': 'Knowsley'},
#  {'href': '', 'id': 'E08000012', 'label': 'Liverpool'},
#  {'href': '', 'id': 'E08000013', 'label': 'St. Helens'},
#  {'href': '', 'id': 'E08000014', 'label': 'Sefton'},
#  {'href': '', 'id': 'E08000015', 'label': 'Wirral'},
#  {'href': '', 'id': 'E08000016', 'label': 'Barnsley'},
#  {'href': '', 'id': 'E08000017', 'label': 'Doncaster'},
#  {'href': '', 'id': 'E08000018', 'label': 'Rotherham'},
#  {'href': '', 'id': 'E08000019', 'label': 'Sheffield'},
#  {'href': '', 'id': 'E08000021', 'label': 'Newcastle upon Tyne'},
#  {'href': '', 'id': 'E08000022', 'label': 'North Tyneside'},
#  {'href': '', 'id': 'E08000023', 'label': 'South Tyneside'},
#  {'href': '', 'id': 'E08000024', 'label': 'Sunderland'},
#  {'href': '', 'id': 'E08000025', 'label': 'Birmingham'},
#  {'href': '', 'id': 'E08000026', 'label': 'Coventry'},
#  {'href': '', 'id': 'E08000027', 'label': 'Dudley'},
#  {'href': '', 'id': 'E08000028', 'label': 'Sandwell'},
#  {'href': '', 'id': 'E08000029', 'label': 'Solihull'},
#  {'href': '', 'id': 'E08000030', 'label': 'Walsall'},
#  {'href': '', 'id': 'E08000031', 'label': 'Wolverhampton'},
#  {'href': '', 'id': 'E08000032', 'label': 'Bradford'},
#  {'href': '', 'id': 'E08000033', 'label': 'Calderdale'},
#  {'href': '', 'id': 'E08000034', 'label': 'Kirklees'},
#  {'href': '', 'id': 'E08000035', 'label': 'Leeds'},
#  {'href': '', 'id': 'E08000036', 'label': 'Wakefield'},
#  {'href': '', 'id': 'E08000037', 'label': 'Gateshead'},
#  {'href': '', 'id': 'E09000001', 'label': 'City of London'},
#  {'href': '', 'id': 'E09000002', 'label': 'Barking and Dagenham'},
#  {'href': '', 'id': 'E09000003', 'label': 'Barnet'},
#  {'href': '', 'id': 'E09000004', 'label': 'Bexley'},
#  {'href': '', 'id': 'E09000005', 'label': 'Brent'},
#  {'href': '', 'id': 'E09000006', 'label': 'Bromley'},
#  {'href': '', 'id': 'E09000007', 'label': 'Camden'},
#  {'href': '', 'id': 'E09000008', 'label': 'Croydon'},
#  {'href': '', 'id': 'E09000009', 'label': 'Ealing'},
#  {'href': '', 'id': 'E09000010', 'label': 'Enfield'},
#  {'href': '', 'id': 'E09000011', 'label': 'Greenwich'},
#  {'href': '', 'id': 'E09000012', 'label': 'Hackney'},
#  {'href': '', 'id': 'E09000013', 'label': 'Hammersmith and Fulham'},
#  {'href': '', 'id': 'E09000014', 'label': 'Haringey'},
#  {'href': '', 'id': 'E09000015', 'label': 'Harrow'},
#  {'href': '', 'id': 'E09000016', 'label': 'Havering'},
#  {'href': '', 'id': 'E09000017', 'label': 'Hillingdon'},
#  {'href': '', 'id': 'E09000018', 'label': 'Hounslow'},
#  {'href': '', 'id': 'E09000019', 'label': 'Islington'},
#  {'href': '', 'id': 'E09000020', 'label': 'Kensington and Chelsea'},
#  {'href': '', 'id': 'E09000021', 'label': 'Kingston upon Thames'},
#  {'href': '', 'id': 'E09000022', 'label': 'Lambeth'},
#  {'href': '', 'id': 'E09000023', 'label': 'Lewisham'},
#  {'href': '', 'id': 'E09000024', 'label': 'Merton'},
#  {'href': '', 'id': 'E09000025', 'label': 'Newham'},
#  {'href': '', 'id': 'E09000026', 'label': 'Redbridge'},
#  {'href': '', 'id': 'E09000027', 'label': 'Richmond upon Thames'},
#  {'href': '', 'id': 'E09000028', 'label': 'Southwark'},
#  {'href': '', 'id': 'E09000029', 'label': 'Sutton'},
#  {'href': '', 'id': 'E09000030', 'label': 'Tower Hamlets'},
#  {'href': '', 'id': 'E09000031', 'label': 'Waltham Forest'},
#  {'href': '', 'id': 'E09000032', 'label': 'Wandsworth'},
#  {'href': '', 'id': 'E09000033', 'label': 'Westminster'},
#  {'href': '', 'id': 'W06000001', 'label': 'Isle of Anglesey'},
#  {'href': '', 'id': 'W06000002', 'label': 'Gwynedd'},
#  {'href': '', 'id': 'W06000003', 'label': 'Conwy'},
#  {'href': '', 'id': 'W06000004', 'label': 'Denbighshire'},
#  {'href': '', 'id': 'W06000005', 'label': 'Flintshire'},
#  {'href': '', 'id': 'W06000006', 'label': 'Wrexham'},
#  {'href': '', 'id': 'W06000008', 'label': 'Ceredigion'},
#  {'href': '', 'id': 'W06000009', 'label': 'Pembrokeshire'},
#  {'href': '', 'id': 'W06000010', 'label': 'Carmarthenshire'},
#  {'href': '', 'id': 'W06000011', 'label': 'Swansea'},
#  {'href': '', 'id': 'W06000012', 'label': 'Neath Port Talbot'},
#  {'href': '', 'id': 'W06000013', 'label': 'Bridgend'},
#  {'href': '', 'id': 'W06000014', 'label': 'Vale of Glamorgan'},
#  {'href': '', 'id': 'W06000015', 'label': 'Cardiff'},
#  {'href': '', 'id': 'W06000016', 'label': 'Rhondda Cynon Taf'},
#  {'href': '', 'id': 'W06000018', 'label': 'Caerphilly'},
#  {'href': '', 'id': 'W06000019', 'label': 'Blaenau Gwent'},
#  {'href': '', 'id': 'W06000020', 'label': 'Torfaen'},
#  {'href': '', 'id': 'W06000021', 'label': 'Monmouthshire'},
#  {'href': '', 'id': 'W06000022', 'label': 'Newport'},
#  {'href': '', 'id': 'W06000023', 'label': 'Powys'},
#  {'href': '', 'id': 'W06000024', 'label': 'Merthyr Tydfil'}]
